# %% [markdown]
# ### Read Source Image

# %%
import cv2

img = cv2.imread("images/mainimage2.jpg")
cv2.imshow('image', img)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
imgN = cv2.imread("data/img_6970.jpg")
imgN.shape
# Out:
# (500, 793, 3)

# %%
imgN = cv2.resize(img, (300, 200))
imgN.shape
cv2.imshow("img", imgN)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Draw a line on image
imgLine = img.copy()
cv2.line(imgLine, (0,0), (150,150), (255,0,255), 5)
cv2.imshow('image', imgLine)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
# Draw a rectangle
imgRect = img.copy()
cv2.rectangle(imgRect, (15,25),(200,150),(0,255,0),5)
cv2.imshow('image', imgRect)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
# Draw a circle
imgCircle = img.copy()
cv2.circle(imgCircle, (100,63), 55, (0,0,255),-1)
cv2.imshow('image', imgCircle)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
import numpy as np
imgPoly = img.copy()
pts = np.array([[20,5],[10,150],[350,330],[250,110]], np.int32)
#pts = pts.reshape(-1,1,2)
cv2.polylines(imgPoly, [pts], True, (0,255,255),3)
cv2.imshow('image', imgPoly)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
imgText = img.copy()
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(imgText, 'OpenCv Tutx!', (0,130), font, 2, (0,255,0), 4, cv2.LINE_AA)
cv2.imshow('image', imgText)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
watch_fc = img.copy()
watch_face = watch_fc[37:111, 107:194]
cv2.imshow('image', watch_face)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('images/Capture.PNG')
retval, threshold = cv2.threshold(img, 12, 255, cv2.THRESH_BINARY)

grayScaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval2, threshold2 = cv2.threshold(grayScaled, 12, 255, cv2.THRESH_BINARY)

'''
In image processing, a Gaussian blur (also known as Gaussian smoothing) is the result of blurring an image by a Gaussian
function (named after mathematician and scientist Carl Friedrich Gauss). It is a widely used effect in graphics software,
typically to reduce image noise and reduce detail.
'''
gaus  = cv2.adaptiveThreshold(grayScaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 155, 1)

retval2, otsu = cv2.threshold(grayScaled, 12, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)



cv2.imshow('original', img)
cv2.imshow('threshold',threshold)
cv2.imshow('threshold2',threshold2)
cv2.imshow('gaus',gaus)
#clustering-based image thresholding, or, the reduction of a graylevel image to a binary image.
cv2.imshow('otsu',otsu)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 12.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
w=100
h=100
fig=plt.figure(figsize=(12, 12))
columns = 5
rows = 5
c = 1
for img in os.listdir("data"):
    img = cv2.imread("data/" + img)
    img = cv2.resize(img, (w, h))
    fig.add_subplot(rows, columns, c)
    c += 1
    plt.imshow(img)
plt.show()
